# %% [markdown]
# # Reinforcement Learning Bonus: DDPG

# %% [markdown]
# - As before, please do not modify the folder architecture and do not rename some of the files.
#
# - You will need to fill in the model.py and DDPG.py to solve the DoublePendulum environment.
# - Because this is a bonus, there will be no test cases.
# - This entire part will be worth 5 points of extra credit for project 4, and will be due on the same day as project 4, so June 6th.
#
# To avoid pain with installation and model training, we strongly recommend you to use Colab for this project. DO NOT use Windows for this project.

# %% [markdown]
# ## Set up

# %%
# %load_ext autoreload
# %autoreload 2
import platform
system = platform.system()
if system == "Linux":
    # %env MUJOCO_GL=egl
elif system == "Darwin":
    # %env MUJOCO_GL=glfw
# %env MUJOCO_GL=egl
# Out:
# env: MUJOCO_GL=glfw

# %%
from utils import *

# %% [markdown]
# ## Introduction to the Enviroment
# We will be training a DDPG agent to solve the DoublePendulum environment. The DoublePendulum environment is a classic control problem where the goal is to balance a double pendulum on a cart.
# #### Action Space
# The agent can apply a force to the cart in the range of -1 to 1. This is a continuous action space.
# #### Observation Space
# The observation space is a 9 dimensional vector. The first 1 is the position of the cart, the next 4 are the cosines and sins of different angles of the double pendulum, and the next 3 are the velocities of the cart and the pendulum, and the final 1 is the constrain forces on the cart. You can find more information about these constraint forces [here](https://homes.cs.washington.edu/~todorov/papers/TodorovICRA14.pdf)
# #### Reward
# The reward can be decomposed into 3 parts. The first part is an alive bonus that pays +10 for every time step the second pendulum is upright. There are 2 penalty terms, one for the tip of the second pendulum moving too much, and another for the cart moving too fast.
#
# You can find more information about the environment [here](https://gymnasium.farama.org/environments/mujoco/inverted_double_pendulum/)
#
# First let us visualize the game and understand the environment.

# %%
import gymnasium as gym
import numpy as np
env = gym.make("InvertedDoublePendulum-v5")
env.np_random = np.random.RandomState(42)

eval_env = gym.make("InvertedDoublePendulum-v5", render_mode="rgb_array")
eval_env.np_random = np.random.RandomState(42)

# %%
from IPython.display import HTML

frames = []
s, _ = eval_env.reset()

while True:
    a = eval_env.action_space.sample()
    s, r, terminated, truncated, _ = eval_env.step(a)
    frames.append(eval_env.render())
    if terminated or truncated:
        break

anim = animate(frames)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img73c9199d181f4ac0b53b20d52377da0f">
#   <div class="anim-controls">
#     <input id="_anim_slider73c9199d181f4ac0b53b20d52377da0f" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim73c9199d181f4ac0b53b20d52377da0f.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim73c9199d181f4ac0b53b20d52377da0f.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim73c9199d181f4ac0b53b20d52377da0f.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim73c9199d181f4ac0b53b20d52377da0f.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim73c9199d181f4ac0b53b20d52377da0f.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim73c9199d181f4ac0b53b20d52377da0f.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim73c9199d181f4ac0b53b20d52377da0f.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim73c9199d181f4ac0b53b20d52377da0f.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim73c9199d181f4ac0b53b20d52377da0f.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim73c9199d181f4ac0b53b20d52377da0f.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select73c9199d181f4ac0b53b20d52377da0f"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_73c9199d181f4ac0b53b20d52377da0f"
#              >
#       <label for="_anim_radio1_73c9199d181f4ac0b53b20d52377da0f">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_73c9199d181f4ac0b53b20d52377da0f"
#              checked>
#       <label for="_anim_radio2_73c9199d181f4ac0b53b20d52377da0f">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_73c9199d181f4ac0b53b20d52377da0f"
#              >
#       <label for="_anim_radio3_73c9199d181f4ac0b53b20d52377da0f">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img73c9199d181f4ac0b53b20d52377da0f";
#     var slider_id = "_anim_slider73c9199d181f4ac0b53b20d52377da0f";
#     var loop_select_id = "_anim_loop_select73c9199d181f4ac0b53b20d52377da0f";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAD2lJRE

# %% [markdown]
# ## Model (1 point)
# Because the inputs to the model is a 9 dimensional vector, we will use a MLP. Specifically we will follow the architecture in the DDPG paper. For DDPG we have both an Actor and a Critic. The Actor is responsible for selecting the action, and the Critic is responsible for evaluating the action.
# #### Actor
# The Actor is a 3 layer MLP:
# - Layer 1: 400 units, ReLU activation, Fan-in weight initialization, ie each weight is initialized with a uniform distribution in the range of -1/sqrt(fan_in) to 1/sqrt(fan_in)
# - Layer 2: 300 units, ReLU activation, Fan-in weight initialization, ie each weight is initialized with a uniform distribution in the range of -1/sqrt(fan_in) to 1/sqrt(fan_in)
# - Layer 3: 1 unit, tanh activation, intialized with uniform weights in the range of -0.003 to 0.003
# #### Critic
# The Critic is a 3 layer MLP:
# - Layer 1: 400 units, ReLU activation, Fan-in weight initialization, ie each weight is initialized with a uniform distribution in the range of -1/sqrt(fan_in) to 1/sqrt(fan_in)
# - Layer 2: 300 units, ReLU activation, Fan-in weight initialization, ie each weight is initialized with a uniform distribution in the range of -1/sqrt(fan_in) to 1/sqrt(fan_in). Input is the concatenation of the 400 dimension embedding from the state, and the action taken.
# - Layer 3: 1 unit, intialized with uniform weights in the range of -0.003 to 0.003

# %%
import model

# %% [markdown]
# ## Exploration (1 point)
# Because DDPG is an off policy algorithm, we will use a noise process to encourage exploration. Specifically we will use the Ornstein-Uhlenbeck process. The Ornstein-Uhlenbeck process is a stochastic process that generates temporally correlated noise. The process is defined by the following stochastic differential equation:
# $$dx_t = \theta(\mu - x_t)dt + \sigma dW_t$$
# Where $\theta$ is the rate of mean reversion, $\mu$ is the long run mean of the process, $\sigma$ is the volatility of the process, and $W_t$ is a Wiener process. We can discretize this process to get the following:
# $$x_{t+1} = x_t + \theta(\mu - x_t)dt + \sigma \sqrt{dt}\mathcal{N}(0,1)$$
# Where $N(0,1)$ is a sample from the standard normal distribution. We will asume that our steps are of unit length, so we can simplify this to:
# $$x_{t+1} = x_t + \theta(\mu - x_t) + \sigma \mathcal{N}(0,1)$$
# We will use $\theta = 0.15$, $\mu = 0$, and $\sigma = 0.2$. We will add this to our action in the following way
# $$a_t = \min(\max(\mu(s_t) + x_t, -1), 1)$$
# Where $a_t$ is the action taken by the agent, $\mu(s_t)$ is the action selected by the actor, and $x_t$ is the noise generated by the Ornstein-Uhlenbeck process.
# Please implement the `OU_Noise` class in DDPG.py

# %% [markdown]
# ## DDPG (3 points total)
# We will be implementing the DDPG algorithm. The DDPG algorithm is a model free, off policy algorithm that combines the actor-critic architecture with the insights of DQN. The algorithm is as follows:
# ![DDPG](DDPG.png)
# Fill in both of the TODO in the `DDPG` class in DDPG.py

# %%
import DDPG
import utils
t = DDPG.DDPG(env,
            model.Actor,
            model.Critic,
            buffer_size=10_000,
            device="mps",
            use_wandb=False,
            save_path = utils.get_save_path("DDPG","./runs/"))

t.train(episodes=10000,
        val_freq=100,
        val_episodes=100,
        test_episodes=1000,
        save_every=100,
        train_every=1)
# Out:
# saving to ./runs/DDPG/run2
# Episode 0: Time: 0.014966011047363281, Total Reward: 44.91817192670272, Q Loss: 0, Actor Loss: 0
# /Users/paultalma/Documents/UCLA/Work/Classes/2024-2025/ee_239/projects/project_4/bonus/replay_buffer.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   states.append(torch.tensor(state, dtype=torch.float32))
# Validation Mean: 21.616539367087675, Validation Std: 4.169852506370168
# saving model
# Validation Mean: 21.407055080994713, Validation Std: 4.172366861806317
# saving model
# Validation Mean: 20.994426546402064, Validation Std: 4.17928762460051
# saving model
# Validation Mean: 21.665370935212454, Validation Std: 4.1347054558734895
# saving model
# Validation Mean: 21.575294415782746, Validation Std: 4.155551113763726
# saving model
# Validation Mean: 21.412239050444626, Validation Std: 4.162453726939085
# saving model
# Validation Mean: 117.11294432737479, Validation Std: 38.1290126866403
# saving model
# Validation Mean: 116.3769669184099, Validation Std: 28.821277972881568
# saving model
# Validation Mean: 114.84412652918874, Validation Std: 35.5514165952769
# saving model
# Validation Mean: 111.46447604977975, Validation Std: 35.731100845955304
# saving model
# Episode 1000: Time: 0.11062812805175781, Total Reward: 110.1914669213545, Q Loss: 165.97825622558594, Actor Loss: -236.53173828125
# Validation Mean: 136.7974199547261, Validation Std: 35.49700653450453
# saving model
# Validation Mean: 126.31074353747819, Validation Std: 37.34043995177323
# saving model
# Validation Mean: 110.02027872288149, Validation Std: 33.68625812165036
# saving model
# Validation Mean: 120.19706774273176, Validation Std: 37.9049837904862
# saving model
# Validation Mean: 165.91588202263162, Validation Std: 34.134567385156934
# saving model
# Validation Mean: 251.96887185823402, Validation Std: 88.20095560715232
# saving model
# Validation Mean: 371.53558988282583, Validation Std: 147.11114784773577
# saving model
# Validation Mean: 393.91498503319167, Validation Std: 140.90290016194135
# saving model
# Validation Mean: 369.30409734200117, Validation Std: 112.69241636065422
# saving model
# Validation Mean: 374.34067604470624, Validation Std: 111.46557873319207
# saving model
# Episode 2000: Time: 0.20441889762878418, Total Reward: 212.45525062416905, Q Loss: 16390.3828125, Actor Loss: -436.13458251953125
# Validation Mean: 373.7128883531472, Validation Std: 112.60991033871984
# saving model
# Validation Mean: 466.0453050390594, Validation Std: 126.3719353792217
# saving model
# Validation Mean: 1053.3297622409214, Validation Std: 347.3514580077873
# saving model
# Validation Mean: 8996.907914399268, Validation Std: 1776.4759885030917
# saving model
# Validation Mean: 8297.563072204626, Validation Std: 2874.6580100856854
# saving model
# Validation Mean: 5027.050565232339, Validation Std: 4509.55620175792
# saving model
# Validation Mean: 2806.309950531011, Validation Std: 3986.326032576456
# saving model
# Validation Mean: 299.06424662863384, Validation Std: 47.73309631554279
# saving model
# Validation Mean: 534.445771860057, Validation Std: 337.30340940692537
# saving model
# Validation Mean: 1105.9548754103307, Validation Std: 1022.3891920592255
# saving model
# Episode 3000: Time: 0.22127604484558105, Total Reward: 230.2308838524705, Q Loss: 5288102.5, Actor Loss: 17696.958984375
# Validation Mean: 727.7663784112973, Validation Std: 792.3765004878472
# saving model
# Validation Mean: 72.8817893505171, Validation Std: 161.94590932756694
# saving model
# Validation Mean: 34.80813653386133, Validation Std: 17.046671711206404
# saving model
# Validation Mean: 31.688935976088864, Validation Std: 17.089297997346353
# saving model
# Validation Mean: 25.84584338098672, Validation Std: 7.904937311747701
# saving model
# Validation Mean: 23.193475302870226, Validation Std: 6.4058615362768485
# saving model
# Validation Mean: 24.663796542678266, Validation Std: 6.5756163296039984
# saving model
# Validation Mean: 25.52851856071049, Validation Std: 3.921891967644472
# saving model
# Validation Mean: 24.705456509170862, Validation Std: 3.432524463357117
# saving model
# Validation Mean: 25.790146846384367, Validation Std: 2.442951321791219
# saving model
# Episode 4000: Time: 0.033632755279541016, Total Reward: 25.81997342319923, Q Loss: 849379.8125, Actor Loss: -6232.13525390625
# Validation Mean: 25.73178879859222, Validation Std: 0.1285916048180701
# saving model
# Validation Mean: 25.495804601127947, Validation Std: 1.247666340770649
# saving model
# Validation Mean: 25.570041260010747, Validation Std: 0.8952913160048483
# saving model
# Validation Mean: 25.65359960479689, Validation Std: 0.14492868499479783
# saving model
# Validation Mean: 25.26596452582546, Validation Std: 1.723049436178272
# saving model
# Validation Mean: 25.081400536954924, Validation Std: 2.088807018335503
# saving model
# Validation Mean: 25.583286893490843, Validation Std: 0.8893539562443805
# saving model
# Validation Mean: 24.799311781975995, Validation Std: 2.506557815577962
# saving model
# Validation Mean: 24.366334013197978, Validation Std: 3.038415898840609
# saving model
# Validation Mean: 25.46366927635422, Validation Std: 1.2337812028813386
# saving model
# Episode 5000: Time: 0.03229212760925293, Total Reward: 25.592192093459953, Q Loss: 129501.4296875, Actor Loss: -15148.27734375
# Validation Mean: 25.02475872967076, Validation Std: 2.252824786530127
# saving model
# Validation Mean: 23.649566087665402, Validation Std: 3.597509620974189
# saving model
# Validation Mean: 24.986509266541404, Validation Std: 2.235037195222356
# saving model
# Validation Mean: 24.65266833482685, Validation Std: 2.7467249184264917
# saving model
# Validation Mean: 24.56420654512599, Validation Std: 2.83797494365635
# saving model
# Validation Mean: 24.486053426063613, Validation Std: 2.9670290044308203
# saving model
# Validation Mean: 24.38646528390728, Validation Std: 3.0304610299216903
# saving model
# Validation Mean: 25.35928866303113, Validation Std: 1.5080148107179776
# saving model
# Validation Mean: 24.39875128464139, Validation Std: 3.0491448900071014
# saving model
# Validation Mean: 25.490732782997075, Validation Std: 1.2404571582292794
# saving model
# Episode 6000: Time: 0.039888858795166016, Total Reward: 34.90815968969238, Q Loss: 69761.1953125, Actor Loss: -22862.52734375
# Validation Mean: 25.457044776981597, Validation Std: 1.5273962222491002
# saving model
# Validation Mean: 25.46608306905307, Validation Std: 1.526228832723859
# saving model
# Validation Mean: 25.636310946937687, Validation Std: 0.888720776111
# saving model
# Validation Mean: 25.76298788251045, Validation Std: 0.17953232964650623
# saving model
# Validation Mean: 25.750928696808106, Validation Std: 0.16711611259200276
# saving model
# Validation Mean: 25.712076282578455, Validation Std: 0.14296057951787897
# saving model
# Validation Mean: 25.37228642946678, Validation Std: 1.5104922695115426
# saving model
# Validation Mean: 25.419909623392233, Validation Std: 1.2354126971172648
# saving model
# Validation Mean: 22.91440189278829, Validation Std: 3.9620687053845023
# saving model
# Validation Mean: 20.848981011346183, Validation Std: 4.19829090670333
# saving model
# Episode 7000: Time: 0.025880098342895508, Total Reward: 16.859332278249248, Q Loss: 102401.71875, Actor Loss: -14126.2099609375
# Validation Mean: 21.39791532660467, Validation Std: 4.16323444521903
# saving model
# Validation Mean: 21.478797582073984, Validation Std: 4.163100555036262
# saving model
# Validation Mean: 21.229845431290425, Validation Std: 4.172773536981353
# saving model
# Validation Mean: 20.90892373321956, Validation Std: 4.173368995033107
# saving model
# Validation Mean: 21.564691136529532, Validation Std: 4.143054337352185
# saving model
# Validation Mean: 21.486176785118733, Validation Std: 4.161692564781276
# saving model
# Validation Mean: 20.81986632049832, Validation Std: 4.170717347572593
# saving model
# Validation Mean: 21.911488326255668, Validation Std: 4.091708375909143
# saving model
# Validation Mean: 20.46900605606435, Validation Std: 4.1445880435823845
# saving model
# Validation Mean: 20.90353596021535, Validation Std: 4.177911003315835
# saving model
# Episode 8000: Time: 0.032442331314086914, Total Reward: 25.757864419586646, Q Loss: 120512072.0, Actor Loss: -66591.609375
# Validation Mean: 21.23263767403425, Validation Std: 4.1652034190506475
# saving model
# Validation Mean: 20.811871528327355, Validation Std: 4.1756442422547915
# saving model
# Validation Mean: 21.073720785089662, Validation Std: 4.164207948275239
# saving model
# Validation Mean: 21.662111993411436, Validation Std: 4.131445523044197
# saving model
# Validation Mean: 21.65275855597934, Validation Std: 4.135536104687811
# saving model
# Validation Mean: 21.82680545885787, Validation Std: 4.111570815066001
# saving model
# Validation Mean: 21.652262587275835, Validation Std: 4.134522307290887
# saving model
# Validation Mean: 20.486778502144293, Validation Std: 4.136499911718155
# saving model
# Validation Mean: 21.14496736794872, Validation Std: 4.172903467268374
# saving model
# Validation Mean: 21.38860538069145, Validation Std: 4.1620139714213344
# saving model
# Episode 9000: Time: 0.03224611282348633, Total Reward: 25.5442925866248, Q Loss: 4235606784.0, Actor Loss: -482159.5625
# Validation Mean: 21.49907296456546, Validation Std: 4.156752967347412
# saving model
# Validation Mean: 21.819564785974407, Validation Std: 4.097556878681053
# saving model
# Validation Mean: 21.56680058646296, Validation Std: 4.1382284662550415
# saving model
# Validation Mean: 20.905585952063316, Validation Std: 4.175064402552723
# saving model
# Validation Mean: 21.250764727210594, Validation Std: 4.17605543752649
# saving model
# Validation Mean: 21.397450796724307, Validation Std: 4.167905739983237
# saving model
# Validation Mean: 21.169081059561822, Validation Std: 4.16294030747982
# saving model
# Validation Mean: 20.402612317267614, Validation Std: 4.127761075154213
# saving model
# Validation Mean: 21.322208403710512, Validation Std: 4.163475986076415
# saving model
# Validation Mean: 21.567959609543582, Validation Std: 4.1471146092782725
# saving model
# Test Mean: 9178.148512252294, Test Std: 1270.1753489509138

# %% [markdown]
# Like what we did for the DQN, we can also animate one episode of the agent in the DoublePendulum environment.

# %%
total_rewards, frames = t.play_episode(0,True,42,eval_env)
anim = animate(frames)
print(total_rewards)
HTML(anim.to_jshtml())
# Out:
# 9359.891271463925
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img05e883cb78cd484ba548b8dfbf1127d7">
#   <div class="anim-controls">
#     <input id="_anim_slider05e883cb78cd484ba548b8dfbf1127d7" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim05e883cb78cd484ba548b8dfbf1127d7.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim05e883cb78cd484ba548b8dfbf1127d7.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select05e883cb78cd484ba548b8dfbf1127d7"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_05e883cb78cd484ba548b8dfbf1127d7"
#              >
#       <label for="_anim_radio1_05e883cb78cd484ba548b8dfbf1127d7">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_05e883cb78cd484ba548b8dfbf1127d7"
#              checked>
#       <label for="_anim_radio2_05e883cb78cd484ba548b8dfbf1127d7">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_05e883cb78cd484ba548b8dfbf1127d7"
#              >
#       <label for="_anim_radio3_05e883cb78cd484ba548b8dfbf1127d7">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img05e883cb78cd484ba548b8dfbf1127d7";
#     var slider_id = "_anim_slider05e883cb78cd484ba548b8dfbf1127d7";
#     var loop_select_id = "_anim_loop_select05e883cb78cd484ba548b8dfbf1127d7";
#     var frames = new Array(1000);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAADh9

# %% [markdown]
# As we can see, the agent is able to balance the double pendulum and it eventually reaches the equilibrium. However this equilibrium is not a stable equilibrium, so lets see how this model performs with perturbations. To do this, we will perturbe the model every 49 steps with a large input of $\pm 0.75$ N to the cart. We will see how the model performs with this perturbation.

# %%
import torch
t.actor.to("cpu")
t.critic.to("cpu")

frames = []
scores = 0
(s, _), done, ret = eval_env.reset(seed = 42
                                   ), False, 0
t.actor.eval()
S = []
outputs = []
# s, r, terminated, truncated, info = eval_env.step(3)
i = 0
with torch.no_grad():
    while not done:
        # if random.random() < 0.1:
        #     action = random.randint(0,4)
        # else:
        frames.append(eval_env.render())
        output = t.actor(torch.tensor(s).unsqueeze(0).to("cpu").float())
        i+=1
        if i%50 == 49:
            output += 0.75*(np.sign(torch.randn_like(output)))
        s_prime, r, terminated, truncated, info = eval_env.step(output.cpu().numpy().squeeze(0))
        s = s_prime
        ret += r
        done = terminated or truncated

scores += ret
# Out:
# /var/folders/vf/jl7g7_r119q9_k8l09dx3vz80000gn/T/ipykernel_2176/3673551052.py:23: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   output += 0.75*(np.sign(torch.randn_like(output)))

# %%
anim = animate(frames)
print(total_rewards)
HTML(anim.to_jshtml())
# Out:
# 9359.891271463925
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img36527fe8f3d5478386a69f09a38b68c6">
#   <div class="anim-controls">
#     <input id="_anim_slider36527fe8f3d5478386a69f09a38b68c6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim36527fe8f3d5478386a69f09a38b68c6.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim36527fe8f3d5478386a69f09a38b68c6.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim36527fe8f3d5478386a69f09a38b68c6.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim36527fe8f3d5478386a69f09a38b68c6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim36527fe8f3d5478386a69f09a38b68c6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim36527fe8f3d5478386a69f09a38b68c6.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim36527fe8f3d5478386a69f09a38b68c6.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim36527fe8f3d5478386a69f09a38b68c6.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim36527fe8f3d5478386a69f09a38b68c6.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim36527fe8f3d5478386a69f09a38b68c6.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select36527fe8f3d5478386a69f09a38b68c6"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_36527fe8f3d5478386a69f09a38b68c6"
#              >
#       <label for="_anim_radio1_36527fe8f3d5478386a69f09a38b68c6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_36527fe8f3d5478386a69f09a38b68c6"
#              checked>
#       <label for="_anim_radio2_36527fe8f3d5478386a69f09a38b68c6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_36527fe8f3d5478386a69f09a38b68c6"
#              >
#       <label for="_anim_radio3_36527fe8f3d5478386a69f09a38b68c6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img36527fe8f3d5478386a69f09a38b68c6";
#     var slider_id = "_anim_slider36527fe8f3d5478386a69f09a38b68c6";
#     var loop_select_id = "_anim_loop_select36527fe8f3d5478386a69f09a38b68c6";
#     var frames = new Array(172);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAADldJ

# %% [markdown]
# You should see that the model is able to recover from the perturbation and is able to balance the double pendulum.
